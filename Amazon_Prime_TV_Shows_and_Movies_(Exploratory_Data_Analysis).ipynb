# %% [markdown]
# <a href="https://colab.research.google.com/github/earlaisthaarth-cyber/amazon-prime-/blob/main/Amazon_Prime_TV_Shows_and_Movies_(Exploratory_Data_Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies (Exploratory Data Analysis)

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name  -Earla Maanass Sudhesh Isthaarth**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on conducting an in-depth Exploratory Data Analysis (EDA) on a dataset containing TV shows and movies available on Amazon Prime Video. The goal of the analysis was to uncover meaningful insights about platform content distribution, regional availability, viewer-oriented patterns, and potential trends that define Amazon Prime Video’s catalog. By examining key attributes such as title, release year, genre, country of origin, rating, and content type (movie or TV show), the analysis aimed to better understand how Amazon Prime structures its offerings and what characteristics define its streaming library.
#
# The first step was data cleaning and preparation. Since the dataset included null values, inconsistencies, and categorical fields requiring standardization, preprocessing was essential. Missing values were addressed through appropriate techniques, such as imputing unknown ratings or removing incomplete entries where necessary. Text fields for country, genre, and cast often contained multiple entries separated by commas, so they were cleaned to allow better analytical segmentation. Release year and duration fields were also examined for outliers. This ensured a reliable foundation for all subsequent visual and statistical analysis.
#
# Once the data was cleaned, the EDA process examined the distribution of content types. One of the early insights revealed that Amazon Prime Video’s library skews more heavily toward movies than TV shows. This indicates that Amazon Prime may prioritize film licensing, or that its original content strategy favors producing stand-alone films more than series. Investigating release years showed that a significant portion of content appears to be from the 2010s onward, reflecting Amazon’s expansion into streaming during that period and its ability to secure newer titles.
#
# Analyzing genres allowed the project to identify which thematic categories dominate the platform. Drama, comedy, and documentary titles were among the most common, suggesting Amazon Prime caters to a broad general audience with interest in storytelling and factual content. Meanwhile, niche genres such as horror or science fiction appeared in smaller quantities but still contributed to variety. Genre analysis also helped highlight content gaps that Amazon may seek to address in future licensing or production decisions.
#
# The project also examined geographical diversity by studying the countries of origin. Amazon Prime Video’s library is notably international, with significant content coming from the United States, India, and the United Kingdom. This matches Amazon’s large user base in these markets and the platform’s strategic focus on Hindi-language and regional Indian content. Regional analysis further revealed that certain countries specialize in particular genres, adding cultural context to the platform’s global composition.
#
# Ratings distribution was another key focus of the EDA. Most titles fell into the “TV-14” and “R” categories, indicating content suited for adolescents and adults. This suggests that Amazon Prime Video leans toward mature storytelling and may be less focused on child-exclusive programming compared to some competitors. Understanding ratings not only helps describe audience demographics but also informs potential content recommendation strategies.
#
# Finally, the project explored relationships among variables, such as whether newer content tends to receive certain ratings or whether specific genres dominate particular countries. Visualizations—including histograms, bar charts, heatmaps, and box plots—played an essential role in highlighting patterns and presenting findings in a clear and interpretable format.
#
# Overall, this Exploratory Data Analysis project offered a comprehensive overview of Amazon Prime Video’s content catalog. By uncovering trends in genre distribution, content type, regional representation, and rating patterns, the analysis provides valuable insights into how Amazon curates its platform. These findings could support recommendation system development, business strategy decisions, and further research into viewer behavior or content performance.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/earlaisthaarth-cyber

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the rapid expansion of streaming platforms like Amazon Prime Video, understanding the vast library of content has become a challenge. The platform hosts thousands of movies and shows across different genres, countries, and age groups, making it essential to analyze patterns that drive popularity and audience engagement. However, the data is scattered across multiple attributes such as ratings, runtime, cast, and genres, which makes it difficult to identify clear insights. This project aims to perform exploratory data analysis to uncover meaningful trends, evaluate content distribution, and highlight factors that contribute to the success and global reach of Amazon Prime’s content.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze Amazon Prime’s content library to uncover insights that can support data-driven decision-making for content strategy. By examining trends in genres, ratings, release years, popularity, and cast/crew contributions, the goal is to identify what resonates most with audiences. This analysis will help in understanding viewer preferences, optimizing content acquisition or production, and enhancing customer satisfaction. Ultimately, the insights aim to support Amazon Prime in strengthening its competitive edge in the global streaming market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
title_df = pd.read_csv('/content/titles.csv')

# %%
credits_df = pd.read_csv('/content/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
title_df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credits_df.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
title_df.shape
# Out:
# (9871, 15)

# %%
credits_df.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
credits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
title_df.duplicated().sum()
# Out:
# np.int64(3)

# %%
credits_df.duplicated().sum()
# Out:
# np.int64(56)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
title_df.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Visualizing the missing values
credits_df.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
data = pd.merge(title_df, credits_df, on = 'id')

# %%
data
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124174  tm1054116           Baikunth  MOVIE
# 124175  tm1054116           Baikunth  MOVIE
# 124176  tm1054116           Baikunth  MOVIE
# 124177  tm1054116           Baikunth  MOVIE
# 124178  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After getting the first view and some basic investigation I have found that there are 9871 rows & 15 columns in title_df dataframe and 124235 rows & 5 columns in the credit_df dataframe. We also found for duplicated values and found 3 duplicate values in title_df dataframe & 56 duplictate values in credit_df dataframe. We also found for null values and found these number of null values respectively. description-119, age_certification-6487, seasons-8514, imdb_id-667, imdb_score-1021, imdb_votes-1031, tmdb_popularity-547, tmdb_score-2082, character-16287.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
title_df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
credits_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
title_df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
credits_df.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The project uses two datasets — titles.csv and credits.csv — containing detailed information about Amazon Prime content. The titles dataset includes variables such as title, type (Movie/Show), release_year, runtime, genres, age_certification, production_countries, imdb_score, and tmdb_popularity, which describe each piece of content’s characteristics and performance. The credits dataset provides information on the people involved in the content, including name, character, and role (Actor, Director, or Writer). Together, these variables allow for a comprehensive analysis of content distribution, quality, audience ratings, and the creative contributors behind Amazon Prime’s library.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
title_df.nunique()
# Out:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %%
credits_df.nunique()
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Replacing NaN values with 'Not Rated' in the age_certification colum

title_df['age_certification'].fillna('Not Rated', inplace=True)

#Filling null values with mean values in imdb score column
title_df['imdb_score'].fillna(title_df['imdb_score'].mean(), inplace=True)

#Dropping duplicate values from both title_df and credit_df
title_df.drop_duplicates(inplace=True)
credits_df.drop_duplicates(inplace=True)

#Merging title_df dataset and credit_df dataset using 'id' as primary key
merged_df = title_df.merge(credits_df, on='id', how='left')

#Creating a column for decade
title_df['decade'] = (title_df['release_year'] // 10) * 10

#Categorize runtime into Short, Medium, or Long
merged_df['runtime_category'] = ''
for i in range(len(merged_df)):
    if merged_df.loc[i, 'runtime'] < 30:
        merged_df.loc[i, 'runtime_category'] = 'Short'
    elif merged_df.loc[i, 'runtime'] <= 90:
        merged_df.loc[i, 'runtime_category'] = 'Medium'
    else:
        merged_df.loc[i, 'runtime_category'] = 'Long'

#Add column is_movie (1 if movie, 0 if show)
merged_df['is_movie'] = 0
for i in range(len(merged_df)):
    if merged_df.loc[i, 'type'] == 'MOVIE':
        merged_df.loc[i, 'is_movie'] = 1
    else:
        merged_df.loc[i, 'is_movie'] = 0
# Out:
# /tmp/ipython-input-1497135621.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   title_df['age_certification'].fillna('Not Rated', inplace=True)
# /tmp/ipython-input-1497135621.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#Categorize IMDb ratings (Poor, Average, Good, Excellent)
merged_df['rating_category'] = ''
for i in range(len(merged_df)):
    score = merged_df.loc[i, 'imdb_score']
    if pd.isna(score):
        merged_df.loc[i, 'rating_category'] = 'Not Rated'
    elif score < 5:
        merged_df.loc[i, 'rating_category'] = 'Poor'
    elif score < 7:
        merged_df.loc[i, 'rating_category'] = 'Average'
    elif score < 8.5:
        merged_df.loc[i, 'rating_category'] = 'Good'
    else:
        merged_df.loc[i, 'rating_category'] = 'Excellent'

# %%
#General Content Overview KPIs
total_titles = merged_df.shape[0]
total_movies = merged_df[merged_df['type'] == 'MOVIE'].shape[0]
total_shows = merged_df[merged_df['type'] == 'SHOW'].shape[0]
avg_runtime = merged_df['runtime'].mean()
avg_imdb = merged_df['imdb_score'].mean()
oldest_year = merged_df['release_year'].min()
newest_year = merged_df['release_year'].max()

print("Total Titles:", total_titles)
print("Movies:", total_movies)
print("Shows:", total_shows)
print("Average Runtime:", round(avg_runtime, 2))
print("Average IMDb Score:", round(avg_imdb, 2))
print("Release Years Range:", oldest_year, "-", newest_year)
# Out:
# Total Titles: 125186
# Movies: 116685
# Shows: 8501
# Average Runtime: 95.35
# Average IMDb Score: 5.97
# Release Years Range: 1912 - 2022

# %%
# Split multiple genres into separate rows
genres_split = merged_df.dropna(subset=['genres']).copy()
genres_split['genres'] = genres_split['genres'].str.replace('[', '').str.replace(']', '').str.replace("'", "")
genres_split = genres_split.assign(genres=genres_split['genres'].str.split(','))
genres_split = genres_split.explode('genres')
genres_split['genres'] = genres_split['genres'].str.strip()

# Top 10 genres
top_genres = genres_split['genres'].value_counts().head(10)
print(top_genres)

# Average IMDb by genre
avg_imdb_genre = genres_split.groupby('genres')['imdb_score'].mean().sort_values(ascending=False).head(10)
print(avg_imdb_genre)
# Out:
# genres
# drama       70006
# comedy      41493
# thriller    33079
# action      30400
# romance     28633
# crime       20618
# horror      14142
# european    12548
# scifi       11442
# fantasy      8935
# Name: count, dtype: int64
# genres
# documentation    6.874880
# history          6.682058
# reality          6.573309
# war              6.429377
# animation        6.380818
# european         6.336190
# sport            6.256898
# drama            6.228907
# romance          6.121547
# music            6.116504
# Name: imdb_score, dtype: float64

# %%
# Top actors, directors, and writers
top_actors = merged_df[merged_df['role'] == 'ACTOR']['name'].value_counts().head(10)
top_directors = merged_df[merged_df['role'] == 'DIRECTOR']['name'].value_counts().head(10)
top_writers = merged_df[merged_df['role'] == 'WRITER']['name'].value_counts().head(10)

print("Top Actors:\n", top_actors)
print("Top Directors:\n", top_directors)

# Role distribution
role_dist = merged_df['role'].value_counts()
print(role_dist)
# Out:
# Top Actors:
#  name
# George 'Gabby' Hayes    49
# Roy Rogers              45
# Bess Flowers            44
# Gene Autry              40
# Nassar                  37
# Herman Hack             35
# Charles King            35
# George Morrell          34
# Earl Dwire              34
# Forrest Taylor          34
# Name: count, dtype: int64
# Top Directors:
#  name
# Joseph Kane           41
# Sam Newfield          38
# Jay Chapman           34
# Lesley Selander       22
# John English          21
# Harry L. Fraser       21
# William Nigh          20
# Manny Rodriguez       17
# Robert N. Bradbury    17
# George Archainbaud    16
# Name: count, dtype: int64
# role
# ACTOR       115793
# DIRECTOR      8386
# Name: count, dtype: int64

# %%
# Split production countries
countries_split = merged_df.dropna(subset=['production_countries']).copy()
countries_split['production_countries'] = countries_split['production_countries'].str.replace('[', '').str.replace(']', '').str.replace("'", "")
countries_split = countries_split.assign(production_countries=countries_split['production_countries'].str.split(','))
countries_split = countries_split.explode('production_countries')
countries_split['production_countries'] = countries_split['production_countries'].str.strip()

# Top 10 countries
top_countries = countries_split['production_countries'].value_counts().head(10)
print(top_countries)
# Out:
# production_countries
# US    79111
# GB    12574
# IN    11591
# CA     6625
# FR     4861
# DE     3219
#        2745
# JP     2650
# IT     2578
# AU     2195
# Name: count, dtype: int64

# %%
# Count of each certification
cert_count = merged_df['age_certification'].value_counts()
print(cert_count)

# Average IMDb by certification
avg_imdb_cert = merged_df.groupby('age_certification')['imdb_score'].mean().sort_values(ascending=False)
print(avg_imdb_cert)
# Out:
# age_certification
# Not Rated    68329
# R            25941
# PG-13        12506
# PG            9641
# G             3845
# TV-MA         1743
# TV-14         1605
# TV-PG          519
# TV-Y7          365
# TV-Y           320
# TV-G           255
# NC-17          117
# Name: count, dtype: int64
# age_certification
# TV-PG        7.454458
# TV-MA        7.357626
# TV-14        7.234761
# TV-Y7        6.738242
# TV-G         6.634831
# TV-Y         6.410660
# PG-13        6.107513
# PG           6.102564
# G            6.039746
# R            5.923611
# Not Rated    5.858963
# NC-17        5.300653
# Name: imdb_score, dtype: float64

# %%
# Number of releases per year
release_trend = merged_df['release_year'].value_counts().sort_index()

# Average IMDb per year
avg_imdb_year = merged_df.groupby('release_year')['imdb_score'].mean()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In preparing the dataset for analysis, several important data-cleaning and transformation steps were performed to make the information reliable and ready for meaningful insights. Missing values in the age_certification column were replaced with “Not Rated,” and missing IMDb scores were filled using the mean to avoid bias. Duplicate records were removed from both datasets, and the two files were merged using the title ID. Additional engineered features were created, such as decade of release, runtime categories, a movie indicator, and IMDb rating categories. Text-based multi-value fields like genres and production_countries were split and exploded for accurate counting. From this enriched dataset, insights revealed the top actors, directors, and writers, the most common genres, and the highest-rated genres. We also identified leading production countries, the distribution of age certifications, and yearly release trends. Overall, the dataset showed that movies dominate over TV shows, Drama is the most frequent genre, and certain genres and countries consistently produce higher-rated content—offering valuable guidance for content strategy and business decisions.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1: Movies Vs TV Shows Count

# %%
# Chart - 1 Movies Vs TV Shows Count
merged_df['type'].value_counts().plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Movies vs Shows on Amazon Prime')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is the ideal choice for comparing the number of movies versus TV shows because it visually emphasizes differences in magnitude between two categorical groups. The format clearly shows which category has more titles, making it simple and intuitive for viewers to interpret. Since we are dealing with only two categories, a bar chart avoids unnecessary complexity while delivering a direct, easy-to-read comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that movies significantly outnumber TV shows in the dataset, with movies comprising the majority of content. This suggests that historically, film production has been more frequent than TV show production, or that the dataset itself places more emphasis on movies. The large gap between the two categories indicates that viewers and creators have traditionally gravitated toward film as the primary format for storytelling and distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business decisions. Knowing that movies dominate the dataset can guide content platforms to allocate resources and marketing strategies appropriately—favoring movies when targeting broader audiences. Investments in movie-focused recommendations, promotions, or catalog expansion may yield higher engagement.
#
# However, the imbalance also hints at a potential negative insight: underrepresentation of TV shows may signal a gap in content diversity. TV shows are increasingly popular due to binge-watching culture and subscription-based streaming models. If a business relies heavily on movies alone, it may lose opportunities to attract long-term, series-focused viewers. This could limit retention and reduce competitive advantage if viewers seek richer episodic content elsewhere.

# %% [markdown]
# #### Chart - 2: Releases by Year

# %%
# Chart - 2 Releases by Year
merged_df['release_year'].value_counts().sort_index().plot(kind='line', color='green')
plt.title('Content Released per Year')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is the most suitable choice for visualizing releases per year because it clearly illustrates how the number of titles changes over time. Line charts are ideal for time-series data, allowing trends, fluctuations, and long-term patterns to be observed easily. This format helps show whether production levels are rising, falling, or experiencing volatility across different decades, making it more informative than static visualizations such as bar or pie charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a slow and steady rise in releases from the early 1900s to around the 1980s, followed by a sharp and rapid increase from the 2000s onward. This spike aligns with the expansion of digital content creation, streaming platforms, and the reduction of barriers to film production. The peak around the 2018–2020 period suggests a surge in media output, after which we see a sudden drop in the most recent year, likely because the dataset contains incomplete entries for the latest year or due to external industry disruptions such as COVID-19’s impact on production.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business impact. Understanding that production has grown significantly in recent years helps companies anticipate competition, adjust content acquisition strategies, and target periods with rich content availability. For streaming services, the insight highlights the opportunity to tap into recent decades where content volume is highest.
#
# A potential negative-growth insight emerges from the sharp drop in the latest year. While this could be due to incomplete data, if it reflects an actual decline in production, businesses may face challenges like limited new content, slower catalog expansion, or higher competition for fewer titles. Identifying such shifts early allows companies to adjust budgets, diversify content sources, or invest in original productions to mitigate risk.

# %% [markdown]
# #### Chart - 3: Top 10 Genres by Count

# %%
# Chart - 3 Top 10 Genres by Count
genres_split['genres'].value_counts().head(10).plot(kind='bar', color='teal')
plt.title('Top 10 Genres by Count')
plt.xlabel('Genre')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is the most effective visualization for comparing counts across categorical variables such as genres. Since the goal is to highlight which genres appear most frequently in the dataset, a bar chart clearly displays the differences in magnitude between categories. The length of each bar makes it easy to instantly identify the most dominant genres, and the format handles categorical comparisons better than pie charts or line charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that Drama overwhelmingly dominates as the most common genre, followed by Comedy, Thriller, and Action. These genres appear far more frequently than others, indicating they represent the core content output of the dataset. Niche or specialized genres such as horror, scifi, and fantasy appear less frequently. This suggests that the content landscape is highly skewed toward mainstream entertainment genres, reflecting general audience demand and industry production trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# es, the insights can positively support business decisions. By understanding that Drama, Comedy, and Thriller dominate the market, businesses—especially streaming platforms, studios, and distributors—can focus marketing efforts, content curation, and investment on these high-volume genres to maximize consumer reach. These insights also help identify whether a catalog is diversified enough or overly concentrated.
#
# In terms of negative growth, heavy reliance on oversaturated genres could eventually reduce content differentiation, making it harder to stand out in a competitive market. If companies invest only in these dominant genres, they might miss opportunities in emerging or niche genres that could attract unique audience segments. Therefore, while high-count genres offer reliable demand, ignoring lower-volume but high-potential genres could hinder long-term growth.

# %% [markdown]
# #### Chart - 4: Average IMDb by Genre (Top 10)

# %%
# Chart - 4 Average IMDb by Genre (Top 10)
avg_imdb_genre.head(10).plot(kind='bar', color='coral')
plt.title('Top 10 Genres by Average IMDb Rating')
plt.xlabel('Genre')
plt.ylabel('Average IMDb')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing numerical values across distinct categories such as genres. Since the goal is to display and compare the average IMDb ratings for the top genres, the bar chart makes it easy to observe differences in rating magnitudes at a glance. Its straightforward structure allows for clear visualization of which genres outperform others, making it more intuitive than other chart types such as line graphs or scatter plots.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that genres like documentation, history, and reality have the highest average IMDb ratings, suggesting that audiences tend to appreciate content that offers real-life insights or informative storytelling. In contrast, while still relatively high, genres such as music, romance, and european rank slightly lower within the top 10 group. Overall, the insight suggests that viewers value authenticity, cultural storytelling, and knowledge-driven content, which may contribute to higher user ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact. By identifying the highest-rated genres, production companies and streaming platforms can prioritize investments in documentaries, historical content, and reality-based storytelling, which consistently deliver higher audience satisfaction. This targeted approach can improve viewer engagement and retention.
#
# Regarding negative growth, the chart does not directly indicate any declining genres. However, genres with comparatively lower average ratings may generate less viewer enthusiasm, meaning investments in those categories may yield slower growth if not strategically enhanced. Still, since all top 10 genres maintain moderately high ratings, no major negative growth signals appear, but companies should analyze market demand before heavily investing in lower-performing genres.

# %% [markdown]
# #### Chart - 5: Genre vs IMDb Heatmap

# %%
# Chart - 5 Genre vs IMDb Heatmap
genre_pivot = genres_split.pivot_table(index='genres', values='imdb_score', aggfunc='mean').sort_values('imdb_score', ascending=False).head(15)
sns.heatmap(genre_pivot, annot=True, cmap='Blues')
plt.title('Average IMDb Rating by Genre')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heat map was chosen because it visually communicates differences in average IMDb ratings across many genres in a way that is both intuitive and efficient. Genres can number in the dozens, and a heat map allows these categories to be compared using color intensity rather than requiring lengthy axis labels or multiple bar segments. This chart type makes it easy to identify which genres perform strongly or poorly at a glance because the color gradient highlights contrasts more effectively than numeric labels alone. It is particularly useful when analyzing patterns across a single metric—here, the IMDb rating—while preserving the ability to spot subtle variations among many categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heat map reveals that certain genres consistently achieve higher average IMDb ratings, such as documentation, history, reality, animation and war, which appear in the upper range. These genres typically benefit from niche audiences or content grounded in factual storytelling, which often receives strong viewer appreciation. On the lower end, genres like fantasy and comedy show lower average ratings, suggesting more variability in production quality or narrower audience appeal. The chart also shows that mid-tier genres—such as drama, music, romance, and crime—tend to cluster around average ratings, reflecting their broad but competitive nature. Overall, the heat map uncovers clear rating patterns tied to genre characteristics and audience expectations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business impact by helping guide decisions on content acquisition, investment, and strategic development. For example, platforms looking to boost viewer satisfaction may choose to prioritize high-rated genres like documentation or history, which consistently deliver strong reception. Conversely, lower-rated genres such as fantasy may require more targeted investment, refined curation, or improved production strategies to ensure audience engagement. A possible negative-growth insight is that relying heavily on genres with historically low ratings may harm overall platform performance if viewer satisfaction drops. If a catalog becomes saturated with underperforming genres, it can weaken retention and brand perception. However, these same insights can also highlight improvement opportunities—underperforming genres may offer space for innovation, new storytelling approaches, or niche-audience targeting that can convert weaknesses into growth opportunities.

# %% [markdown]
# #### Chart - 6: Top 10 Actors

# %%
# Chart - 6 Top 10 Actors
top_actors.plot(kind='barh', color='mediumseagreen')
plt.title('Top 10 Most Frequent Actors')
plt.xlabel('Count')
plt.ylabel('Actor')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was selected because it is the most effective way to display the top 10 actors based on the number of titles they appear in. Actor names can often be long, and a horizontal layout prevents label overcrowding while keeping the chart clean and readable. Bar charts are ideal for comparing categorical data with numerical values, and in this case, the chart clearly shows how the most prolific actors rank relative to each other. Other chart types—such as pie charts—would not convey differences as effectively, especially when several values are close together.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a few actors—particularly George “Gabby” Hayes, Roy Rogers, and Bess Flowers—appear in significantly more titles than others, suggesting they had extremely active careers or frequently appeared in supporting roles that accumulated over time. The remaining actors show slightly lower but still substantial counts, indicating a group of individuals who consistently participated in film and television productions. This pattern highlights the presence of highly prolific performers who may have been staples in certain genres or periods, reflecting both industry demand and their personal popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business impact by identifying high-visibility actors whose filmographies may attract consistent audience interest. Streaming platforms, archives, or media distributors can leverage this by curating collections, recommending classic titles, or highlighting these actors in marketing campaigns. However, there is also a potential negative insight: relying too heavily on the most prolific actors may overlook quality or shifting audience preferences. High volume does not always equal high demand, and overemphasis on frequently appearing actors could lead to outdated content strategies if their work does not align with modern viewer interests. Balancing popularity insights with genre trends, ratings, and viewer engagement data ensures sustainable growth.

# %% [markdown]
# #### Chart - 7: Top 10 Directors

# %%
# Chart - 7 Top 10 Directors
top_directors.plot(kind='barh', color='plum')
plt.title('Top 10 Most Frequent Directors')
plt.xlabel('Count')
plt.ylabel('Director')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it provides a clear and effective way to compare the number of titles directed by each of the top 10 directors. Since director names can be long, using a horizontal layout avoids overcrowding and ensures the labels remain readable. Bar charts also excel at comparing categorical data against numerical values, making it easy to identify which directors have the highest output. This type of visualization is more suitable than a pie chart, which would struggle to show small differences, and more intuitive than a table, which requires more cognitive effort to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights that a few directors—such as Joseph Kane, Sam Newfield, and Jay Chapman—significantly outpace others in terms of the number of titles they directed. Their production volume stands out strongly, suggesting that these directors were highly active and possibly influential in their respective eras or genres. Meanwhile, the remaining directors in the top 10 show relatively similar output levels, indicating a more balanced distribution among the lower-ranked individuals. This pattern shows that while many directors contribute consistently, a small group drives a disproportionately large share of content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business impact by guiding content acquisition strategies, highlighting prolific directors whose works might attract specific audiences or fill catalog gaps. Platforms, archives, or distributors can use this information to prioritize licensing deals, retrospective collections, or promotional features around high-output directors. On the other hand, a potential negative insight emerges if business decisions rely too heavily on volume alone—high output does not always correlate with high demand or quality. Investing heavily in directors who are prolific but not widely popular could lead to weak viewer engagement, reducing growth. Therefore, this chart is useful when combined with other metrics such as IMDb ratings, genre trends, and audience preferences.

# %% [markdown]
# #### Chart - 8: Role Distribution

# %%
# Chart - 8 Role Distribution
role_dist.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'lightcoral', 'lightskyblue'])
plt.title('Role Distribution (Actor, Director, Writer)')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart was chosen because it visually communicates how the different roles—such as actors and directors—contribute to the overall distribution within the dataset. Pie charts are effective when the goal is to show proportions or percentages of a whole. In this case, the aim is to highlight the dominant role category and how much it outweighs the others. A bar chart or line graph would not convey the same sense of proportional dominance as clearly, whereas the pie chart allows the viewer to instantly grasp which roles are most prevalent in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals that actors make up the overwhelming majority of roles in the dataset, accounting for more than 90% of entries, while directors represent only a small portion. This suggests a heavy emphasis on cast listings compared to production roles. The distribution indicates that most title records are actor-focused, possibly because actors are more numerous per project, while directors are typically limited to one or two per production. This imbalance may also reflect how metadata is collected, with casting details recorded more extensively than behind-the-camera roles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can contribute to positive business impact by helping stakeholders understand the focus and limitations of their current data. For instance, knowing that actor roles dominate the dataset may guide businesses to improve metadata for directors or other crew roles to create more balanced and detailed title profiles. Such improvements can enhance recommendation systems, provide richer content analytics, and support better decision-making for casting or talent-related projects. On the negative side, the heavy imbalance could signal a potential gap in data coverage—underrepresentation of key roles like directors may limit deeper analysis of production influence, creative patterns, or leadership trends. If unaddressed, this gap could hinder growth in analytics-driven decision areas that rely on comprehensive role-based insights.

# %% [markdown]
# #### Chart - 9: Top 10 Production Countries

# %%
# Chart - 9 Top 10 Production Countries
top_countries.plot(kind='bar', color='deepskyblue')
plt.title('Top 10 Production Countries')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it clearly illustrates the differences in production volume among the top 10 countries. When comparing categorical data—such as countries—based on the number of titles they produce, a bar chart offers the most straightforward visual interpretation. It allows the viewer to instantly recognize which countries contribute the most content and how each one compares to others. Other chart types, such as pie charts or line charts, would not provide the same level of clarity when dealing with many categories or when emphasizing direct comparisons. The bar chart's simple structure and ability to highlight variations make it ideal for this type of analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A bar chart was chosen because it clearly illustrates the differences in production volume among the top 10 countries. When comparing categorical data—such as countries—based on the number of titles they produce, a bar chart offers the most straightforward visual interpretation. It allows the viewer to instantly recognize which countries contribute the most content and how each one compares to others. Other chart types, such as pie charts or line charts, would not provide the same level of clarity when dealing with many categories or when emphasizing direct comparisons. The bar chart's simple structure and ability to highlight variations make it ideal for this type of analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create positive business impact by helping organizations understand which countries have the highest production activity, allowing them to prioritize partnerships, content acquisition, or distribution strategies. For example, focusing on countries with high output may increase access to diverse content and improve global market reach. Conversely, insights showing countries with very low production volume could indicate potential challenges, such as limited content availability or less-developed media markets, which may negatively impact growth if a company invests heavily there without supporting infrastructure. However, these lower-producing regions can also represent untapped opportunities—if approached strategically with localized support and investment.

# %% [markdown]
# #### Chart - 10: Average IMDb by Country

# %%
# Chart - 10 Average IMDb by Country
avg_imdb_country = countries_split.groupby('production_countries')['imdb_score'].mean().sort_values(ascending=False).head(10)
avg_imdb_country.plot(kind='bar', color='tomato')
plt.title('Top 10 Countries by Average IMDb Rating')
plt.xlabel('Country')
plt.ylabel('Average IMDb')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected because it is the most effective visualization for comparing numerical values—such as average IMDb ratings—across multiple categorical groups like countries. Since the goal is to examine how countries differ in their aggregated viewer ratings, a bar chart provides a clear, direct comparison of their average scores. This format allows each country to be represented with a distinct bar whose height immediately communicates performance differences. Unlike pie charts or line graphs, which are less suitable for comparing small variations across many categories, bar charts offer precise readability, making them ideal for ranking the top-performing countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart reveals that the top 10 countries with the highest average IMDb ratings tend to have relatively similar rating levels, all clustered around the 7.1 to 7.8 range. This suggests that high-rated content is not concentrated in a single region but is distributed across diverse countries, including AL, PF, LB, GE, and SU. The narrow spread between the highest and lowest averages also indicates that no single country overwhelmingly dominates in terms of producing top-rated shows or movies. Instead, several smaller or less globally prominent production countries appear in the top 10, showing that high-quality content can emerge from a wide geographical base.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business impact by guiding content acquisition and investment strategies. Identifying countries that consistently produce highly rated content allows streaming platforms, distributors, or studios to prioritize partnerships, co-productions, and licensing deals with these regions, potentially improving overall catalog quality and audience satisfaction. However, there may also be cautionary insights: if major content-producing countries do not appear in the top-performing list, it could signal potential stagnation or risk associated with continuing to invest heavily in regions that are not yielding high-rated productions. Overreliance on countries with lower average ratings might lead to weaker audience engagement, reducing long-term growth. Conversely, failing to recognize emerging high-performing regions could cause missed opportunities in expanding global content diversity.

# %% [markdown]
# #### Chart - 11: Certification Distribution

# %%
# Chart - 11 Certification Distribution
merged_df['age_certification'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.legend(title='Age Certification', loc='best')
plt.title('Distribution by Age Certification')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart was selected because it is the most intuitive visualization for showing how a whole is divided into parts—in this case, the proportion of titles within each certification category. Since the goal is to understand the distribution rather than compare numerical performance or trends, a pie chart provides a clean, immediate sense of which certifications dominate the dataset and which ones represent smaller shares. Certifications are categorical and mutually exclusive, making them ideal for representation as slices of a whole, and the percentage labels help reinforce how significant each category is relative to the others.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals several key insights about the distribution of certifications in the dataset. The R-rated category is by far the largest, making up over a third of all titles, indicating a strong emphasis on mature content. PG-13 and PG certifications also represent significant shares, suggesting a healthy volume of content aimed at teens and general audiences. In contrast, TV-rated certifications such as TV-Y, TV-PG, and TV-G make up much smaller percentages, showing that the dataset contains relatively fewer family-oriented or child-focused titles. NC-17 content is extremely rare, highlighting either limited production, limited distribution, or both. Overall, the distribution suggests that the catalog is heavily weighted toward content intended for older audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can guide strategic decisions with measurable business impact. Knowing that R, PG-13, and PG certifications dominate the dataset allows a company to align marketing, recommendation algorithms, and licensing efforts with audience demand patterns. If consumer viewing behavior aligns with these distributions, then investing more in mature and teen-focused content could sustain or increase engagement. Conversely, the very small share of family-focused certifications may signal a potential growth opportunity—expanding into G, PG, or TV-Y content could attract families or younger audiences who are currently underserved. However, there is also a potential negative insight: an overconcentration in mature ratings like R could limit audience diversification. If viewer demographics shift or platforms seek to expand into more inclusive markets, relying too heavily on mature content may create stagnation. Balancing the catalog with more varied certifications can help mitigate this risk and foster long-term growth.

# %% [markdown]
# #### Chart - 12: Average IMDb by Certification

# %%
# Chart - 12 Average IMDb by Certification
avg_imdb_cert.plot(kind='bar', color='orchid')
plt.title('Average IMDb Rating by Age Certification')
plt.xlabel('Certification')
plt.ylabel('Average IMDb')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it is the most effective way to compare average IMDb scores across the different age certification categories, which are naturally discrete and categorical. Unlike a line chart or scatter plot, which are more suitable for continuous data or relationships between numerical variables, a bar chart allows each certification type—such as TV-MA, PG, G, or R—to stand on its own with a clear visual height that represents its average rating. This makes it easy to immediately identify which certifications perform better or worse based on viewer ratings. Additionally, bar charts minimize visual clutter and help highlight ranking differences, making them ideal for presenting a simple, direct comparison of group averages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals several meaningful trends in viewer ratings across age certifications. TV-focused certifications such as TV-PG, TV-14, and especially TV-MA have noticeably higher average IMDb scores, suggesting that older-audience or mature-themed TV content tends to receive more favorable viewer reception. In contrast, ratings for theatrical certifications like G, PG, and R hover around the mid-range, indicating that these types of content receive more varied or moderate audience responses. The most striking insight is that NC-17 content has the lowest average ratings, signaling limited viewer satisfaction or niche appeal. Overall, the chart shows a clear pattern where content aimed at teens and adults tends to perform better in terms of audience ratings than content intended for younger audiences or general theatrical release.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can support positive business impact by guiding strategic decisions regarding content development, acquisition, and marketing. Since higher ratings suggest stronger audience engagement and satisfaction, investing more in TV-14 and TV-MA productions could yield better viewer retention and platform loyalty for streaming services or content studios. These insights also allow resource allocation toward the types of content that historically perform best, increasing efficiency and reducing risk. However, the data also highlights potential areas of negative growth, especially for NC-17 content, which consistently shows lower ratings and may not appeal to a wide audience; overinvesting in such content could lead to poor viewership returns and reputational risk. Similarly, the moderate performance of broad family-oriented content suggests that relying heavily on these genres without strong differentiation may not drive significant audience engagement. Thus, the insights help identify both growth opportunities and areas where caution is needed.

# %% [markdown]
# #### Chart - 13: Average IMDb score per Year

# %%
# Chart - 13 Average IMDb score per Year
avg_imdb_year.plot(kind='line', color='navy')
plt.title('Average IMDb Rating Over the Years')
plt.xlabel('Year')
plt.ylabel('Average IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line chart of the number of titles released per year was selected because it is the most effective and intuitive way to visualize how content production has evolved over time. Unlike bar charts or scatter plots, a line chart highlights long-term trends and growth patterns, allowing us to see not just isolated values but the momentum, acceleration, and fluctuations in content creation across decades. This format is ideal for time-series data such as release years, where continuity and direction are key to understanding industry behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, one of the most striking insights is the dramatic increase in the number of titles produced from the early 2000s onward, followed by a particularly sharp rise between 2010 and 2020. This growth aligns with the global expansion of streaming platforms, easier digital distribution, and lower production barriers due to technological advancements. Early decades show slow, steady production, while recent years demonstrate exponential growth, indicating a fundamental shift in media consumption and creation. The notable spike before 2020—and the drop immediately after—may reflect anomalies such as dataset limitations or real-world disruptions like the COVID-19 pandemic halting productions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights have strong implications for business impact. The positive growth in content production suggests expanding opportunities for streaming services, content distributors, marketing agencies, and analytics platforms, as more titles create more engagement and monetization possibilities. However, the steep increase also signals potential negative pressures: market saturation, higher competition for viewer attention, rising production costs, and a crowded release ecosystem where individual titles struggle to stand out. Understanding this balance helps businesses strategize more effectively, invest wisely, and anticipate industry shifts rather than react to them.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
num_col = data.select_dtypes(include=['int64', 'float64'])

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(num_col.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap\n', color="green")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected the heat map because it is one of the most effective tools for quickly assessing patterns across multiple variables simultaneously. Unlike pair plots, which provide detailed scatter relationships, the heat map condenses all correlations into a single, intuitive visual representation, allowing us to instantly identify strong associations, weak connections, and variables that may not contribute much predictive power. This chart is especially useful during early exploration because it helps highlight which features are worth deeper analysis and which may require transformation, removal, or additional cleaning. Its ability to summarize complex numerical interactions in a simple color gradient makes it an ideal choice for guiding data-driven decisions and informing the next steps in the analytical process.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heat map provides a clear, concise visual summary of how the numerical variables in our dataset relate to one another, allowing us to quickly identify the strength and direction of key relationships. From this chart, we observe that IMDb votes have one of the strongest positive correlations with IMDb scores, reinforcing the idea that widely watched or engaged-with titles tend to receive higher ratings. TMDB popularity also shows moderate alignment with IMDb votes and IMDb scores, suggesting consistent audience behavior and cross-platform engagement. In contrast, runtime, number of seasons, and release year demonstrate weak or negligible correlations with most scoring and popularity metrics, indicating that these variables do not significantly influence how audiences rate or interact with titles. The heat map also highlights that TMDB scores correlate only weakly with IMDb scores, reflecting differences in scoring systems or audience expectations. Additionally, the heat map makes it easy to spot skewed or ineffective variables—such as person_id, which shows no meaningful pattern—helping us refine our selection of relevant features.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# chart 15 Pair Plot
sns.pairplot(data)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected the pair plot because it provides a clear, visual overview of how all numerical variables in the dataset relate to one another at once, making it an ideal first step in exploratory data analysis. Given the wide range of fields—such as IMDb score, IMDb votes, TMDB popularity, runtime, seasons, and release year—the pair plot helps quickly reveal which relationships are meaningful and which are weak or nonexistent. For example, the strong positive correlation between IMDb score and IMDb votes becomes immediately visible, reinforcing the idea that popular titles tend to be both highly rated and widely engaged with. Similarly, the rise in TMDB popularity alongside IMDb votes and scores shows consistent cross-platform audience behavior, something that is much harder to detect from raw tables or single plots. The pair plot also highlights variables that offer little predictive value, such as runtime, seasons, or person_id, by showing their scattered or non-correlated patterns across the grid. This makes it easier to identify which features are worth keeping for deeper modeling and which can be deprioritized. Additionally, patterns like skewed release years and clusters of outliers—such as titles with extremely high popularity or unusually long runtimes—are easier to spot visually, helping guide future steps like scaling, transformation, or outlier handling. Overall, the pair plot was chosen because it provides a comprehensive, intuitive, and efficient way to assess relationships, detect patterns, and inform later stages of analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot reveals several important relationships and patterns within the dataset. One of the strongest insights is the clear positive correlation between IMDb scores and IMDb votes, indicating that higher-rated movies and shows tend to attract significantly more audience engagement. This suggests that widely viewed titles not only accumulate more votes but are also more likely to receive higher ratings. TMDB popularity shows a similar trend, rising alongside both IMDb votes and IMDb scores, which highlights consistency across platforms in how audiences interact with popular content. Interestingly, runtime shows no meaningful correlation with either ratings or popularity; long movies are not necessarily better rated, nor are shorter titles disadvantaged. The number of seasons also displays only weak relationships with audience metrics, with most shows clustering between zero and ten seasons and showing no consistent impact on score or popularity. Release year appears heavily skewed toward modern productions but does not strongly influence IMDb scores, though newer titles may receive more votes due to digital accessibility. The comparison between TMDB score and IMDb score shows only a weak connection, suggesting each platform uses distinct scoring behavior. As expected, person_id provides no analytical value and behaves purely as an identifier. Finally, the plot reveals several outliers, including extremely popular titles, very high vote counts, unusually long runtimes, and series with exceptionally many seasons—all of which may affect correlation measures if not normalized.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve its business objectives, Amazon Prime should focus on expanding and promoting content in the most popular genres and regions identified through data insights. Investing in high-performing categories such as top-rated genres and collaborating with successful directors or actors can improve audience engagement. The platform should also analyze viewer preferences based on IMDb and TMDB ratings to recommend personalized content effectively. Additionally, maintaining a balanced mix of new releases and classic titles can attract diverse audiences. By leveraging these insights, Amazon Prime can optimize its content strategy, improve customer retention, and strengthen its market share in the global streaming landscape.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Amazon Prime Exploratory Data Analysis provided valuable insights into the platform’s content trends, audience preferences, and performance metrics. The study revealed that factors such as genre popularity, release year distribution, and IMDb scores play a significant role in determining the success of shows and movies. By analyzing key patterns in ratings, content type, and regional contributions, the project highlights opportunities for Amazon Prime to enhance its content strategy and audience targeting. These findings can help the platform make informed decisions about future investments, improve viewer satisfaction, and maintain a competitive advantage in the rapidly evolving streaming industry. Overall, this data-driven approach demonstrates the power of analytics in shaping business success for entertainment platforms.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
